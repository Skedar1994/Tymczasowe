# %% [markdown]
# # Assignment 5
#
# **Submission deadline: last lab session before or on Tuesday, 09.5.17**
#
# **Points: 9 + 10 bonus points**
#
#
# ## Downloading this notebook
#
# This assignment is an Jupyter notebook. Download it by cloning https://github.com/janchorowski/nn_assignments. Follow the instructions in its README for instructions.
#
# For programming exerciese add your solutions to the notebook. For math exercies please provide us with answers on paper or type them in the notebook (it supports Latex-like equations).
#
# Please do not hesitate to use GitHub’s pull requests to send us corrections!

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Modular network implementation
#
# This assignment builds on code from Assignment 4, Problem 7.
# For your convenience, we have copied the code below. Please copy your solution from the old list, or fill in the blanks below to get a working network.
#
# In the following cells, I implement in a modular way a feedforward neural network. Please study the code - many network implementations follow a similar pattern.
#
# Please make sure that the network trains to nearly 100% accuracy on Iris.
#
# ## Task
#
# Your job is to implement SGD training on MNIST with the following elements:
# 1. SGD + momentum
# 2. weight decay
# 3. early stopping
#
# In overall, you should get below **2% testing errors**

# %%
#
# These are taken from https://github.com/mila-udem/blocks
# 

class Constant():
    """Initialize parameters to a constant.
    The constant may be a scalar or a :class:`~numpy.ndarray` of any shape
    that is broadcastable with the requested parameter arrays.
    Parameters
    ----------
    constant : :class:`~numpy.ndarray`
        The initialization value to use. Must be a scalar or an ndarray (or
        compatible object, such as a nested list) that has a shape that is
        broadcastable with any shape requested by `initialize`.
    """
    def __init__(self, constant):
        self._constant = numpy.asarray(constant)

    def generate(self, rng, shape):
        dest = numpy.empty(shape, dtype=np.float32)
        dest[...] = self._constant
        return dest


class IsotropicGaussian():
    """Initialize parameters from an isotropic Gaussian distribution.
    Parameters
    ----------
    std : float, optional
        The standard deviation of the Gaussian distribution. Defaults to 1.
    mean : float, optional
        The mean of the Gaussian distribution. Defaults to 0
    Notes
    -----
    Be careful: the standard deviation goes first and the mean goes
    second!
    """
    def __init__(self, std=1, mean=0):
        self._mean = mean
        self._std = std

    def generate(self, rng, shape):
        m = rng.normal(self._mean, self._std, size=shape)
        return m.astype(np.float32)


class Uniform():
    """Initialize parameters from a uniform distribution.
    Parameters
    ----------
    mean : float, optional
        The mean of the uniform distribution (i.e. the center of mass for
        the density function); Defaults to 0.
    width : float, optional
        One way of specifying the range of the uniform distribution. The
        support will be [mean - width/2, mean + width/2]. **Exactly one**
        of `width` or `std` must be specified.
    std : float, optional
        An alternative method of specifying the range of the uniform
        distribution. Chooses the width of the uniform such that random
        variates will have a desired standard deviation. **Exactly one** of
        `width` or `std` must be specified.
    """
    def __init__(self, mean=0., width=None, std=None):
        if (width is not None) == (std is not None):
            raise ValueError("must specify width or std, "
                             "but not both")
        if std is not None:
            # Variance of a uniform is 1/12 * width^2
            self._width = numpy.sqrt(12) * std
        else:
            self._width = width
        self._mean = mean

    def generate(self, rng, shape):
        w = self._width / 2
        m = rng.uniform(self._mean - w, self._mean + w, size=shape)
        return m.astype(np.float32)

# %%
class Layer(object):
    def __init__(self, rng=None):
        if rng is None:
            rng = numpy.random
        self.rng = rng
    
    @property
    def parameters(self):
        return []
    
    @property
    def parameter_names(self):
        return []
    
    def get_gradients(self, dLdY, fprop_context):
        return []
    

class AffineLayer(Layer):
    def __init__(self, num_in, num_out, weight_init=None, bias_init=None, **kwargs):
        super(AffineLayer, self).__init__(**kwargs)
        if weight_init is None:
            #
            # TODO propose a default initialization scheme.
            # Type a sentence explaining why, and if you use a reference, 
            # cite it here
            #
            weight_init = Uniform(0, 2/(num_in**0.5))
        if bias_init is None:
            bias_init = Constant(0.0)
        
        self.W = weight_init.generate(self.rng, (num_out, num_in))
        self.b = bias_init.generate(self.rng, (num_out, 1))
    
    @property
    def parameters(self):
        return [self.W, self.b]
    
    @property
    def parameter_names(self):
        return ['W','b']
    
    def fprop(self, X):
        #Save X for later reusal
        fprop_context = dict(X=X)
        Y = np.dot(self.W, X) +  self.b
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        #
        # TODO: fill in gradient computation
        #
        dLdX = np.dot(self.W.T, dLdY)
        return dLdX
    
    def get_gradients(self, dLdY, fprop_context):
        X = fprop_context['X']
        dLdW = np.dot(dLdY, X.T)
        dLdb = dLdY.sum(1, keepdims=True)
        return [dLdW, dLdb]
    
class TanhLayer(Layer):
    def __init__(self, **kwargs):
        super(TanhLayer, self).__init__(**kwargs)
    
    def fprop(self, X):
        Y = np.tanh(X)
        fprop_context = dict(Y=Y)
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        Y = fprop_context['Y']
        #
        # Fill in proper gradient computation
        #
        return dLdY * (1 - (Y**2))

    
class ReLULayer(Layer):
    def __init__(self, **kwargs):
        super(ReLULayer, self).__init__(**kwargs)
    
    def fprop(self, X):
        Y = np.maximum(X, 0.0)
        fprop_context = dict(Y=Y)
        return Y, fprop_context
    
    def bprop(self, dLdY, fprop_context):
        Y = fprop_context['Y']
        return dLdY * (Y>0)

    
class SoftMaxLayer(Layer):
    def __init__(self, **kwargs):
        super(SoftMaxLayer, self).__init__(**kwargs)
    
    def compute_probabilities(self, X):
        O = X - X.max(axis=0, keepdims=True)
        O = np.exp(O)
        O /= O.sum(axis=0, keepdims=True)
        return O
    
    def fprop_cost(self, X, Y):
        NS = X.shape[1]
        O = self.compute_probabilities(X)
        Cost = -1.0/NS * np.log(O[Y.ravel(), range(NS)]).sum()
        return Cost, O, dict(O=O, X=X, Y=Y)
    
    def bprop_cost(self, fprop_context):
        X = fprop_context['X']
        Y = fprop_context['Y']
        O = fprop_context['O']
        NS = X.shape[1]
        dLdX = O.copy()
        dLdX[Y, range(NS)] -= 1.0
        dLdX /= NS
        return dLdX
    
class FeedForwardNet(object):
    def __init__(self, layers=None):
        if layers is None:
            layers = []
        self.layers = layers
    
    def add(self, layer):
        self.layers.append(layer)
    
    @property
    def parameters(self):
        params = []
        for layer in self.layers:
            params += layer.parameters
        return params
    
    @parameters.setter
    def parameters(self, values):
        for ownP, newP in zip(self.parameters, values):
            ownP[...] = newP
    
    @property
    def parameter_names(self):
        param_names = []
        for layer in self.layers:
            param_names += layer.parameter_names
        return param_names
    
    def fprop(self, X):
        for layer in self.layers[:-1]:
            X, fp_context = layer.fprop(X)
        return self.layers[-1].compute_probabilities(X)
    
    def get_cost_and_gradient(self, X, Y):
        fp_contexts = []
        for layer in self.layers[:-1]:
            X, fp_context = layer.fprop(X)
            fp_contexts.append(fp_context)
        
        L, O, fp_context = self.layers[-1].fprop_cost(X, Y)
        dLdX = self.layers[-1].bprop_cost(fp_context)
        
        dLdP = [] #gradient with respect to parameters
        for i in xrange(len(self.layers)-1):
            layer = self.layers[len(self.layers)-2-i]
            fp_context = fp_contexts[len(self.layers)-2-i]
            dLdP = layer.get_gradients(dLdX, fp_context) + dLdP
            dLdX = layer.bprop(dLdX, fp_context)
        return L, O, dLdP

# %%
#training algorithms. They change the network!
def GD(net, X, Y, alpha=1e-4, max_iters=1000000, tolerance=1e-6):
    """
    Simple batch gradient descent
    """
    old_L = np.inf
    for i in xrange(max_iters):
        L, O, gradients = net.get_cost_and_gradient(X, Y)
        if old_L < L:
            print "Iter: %d, loss increased!!" % (i,)
        if (old_L - L)<tolerance:
            print "Tolerance level reached exiting"
            break
        if i % 1000 == 0:
            err_rate = (O.argmax(0) != Y).mean()
            print "At iteration %d, loss %f, train error rate %f%%" % (i, L, err_rate*100)
        for P,G in zip(net.parameters, gradients):
            P -= alpha * G
        old_L = L

# %%
from sklearn import datasets
iris = datasets.load_iris()
IrisX = iris.data.T
IrisX = (IrisX - IrisX.mean(axis=1, keepdims=True)) / IrisX.std(axis=1, keepdims=True)
IrisY = iris.target.reshape(1,-1)

# %%
#
# Here we verify that the network can be trained on Irises.
# Most runs should result in 100% accurracy
#

net = FeedForwardNet([
        AffineLayer(4,10),
        TanhLayer(),
        AffineLayer(10,3),
        SoftMaxLayer()
        ])
GD(net, IrisX,IrisY, 1e-1, tolerance=1e-7, max_iters=50000)
# Out:
# At iteration 0, loss 1.339231, train error rate 97.333333%
# At iteration 1000, loss 0.052988, train error rate 2.000000%
# At iteration 2000, loss 0.043840, train error rate 1.333333%
# At iteration 3000, loss 0.041294, train error rate 1.333333%
# At iteration 4000, loss 0.040071, train error rate 1.333333%
# At iteration 5000, loss 0.039268, train error rate 1.333333%
# At iteration 6000, loss 0.038638, train error rate 1.333333%
# At iteration 7000, loss 0.038093, train error rate 1.333333%
# At iteration 8000, loss 0.037591, train error rate 1.333333%
# At iteration 9000, loss 0.037102, train error rate 1.333333%
# At iteration 10000, loss 0.036605, train error rate 1.333333%
# At iteration 11000, loss 0.036081, train error rate 1.333333%
# At iteration 12000, loss 0.035520, train error rate 1.333333%
# At iteration 13000, loss 0.034915, train error rate 1.333333%
# At iteration 14000, loss 0.034267, train error rate 1.333333%
# At iteration 15000, loss 0.033574, train error rate 1.333333%
# At iteration 16000, loss 0.032821, train error rate 1.333333%
# At iteration 17000, loss 0.031973, train error rate 1.333333%
# At iteration 18000, loss 0.030960, train error rate 1.333333%
# At iteration 19000, loss 0.029688, train error rate 0.666667%
# At iteration 20000, loss 0.028086, train error rate 0.666667%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-62982dba8af5> in <module>()
#      10         SoftMaxLayer()
#      11         ])
# ---> 12 GD(net, IrisX,IrisY, 1e-1, tolerance=1e-7, max_iters=50000)
#
# <ipython-input-4-1f2f9bcc720d> in GD(net, X, Y, alpha, max_iters, tolerance)
#       6     old_L = np.inf
#       7     for i in xrange(max_iters):
# ----> 8         L, O, gradients = net.get_cost_and_gradient(X, Y)
#       9         if old_L < L:
#      10             print "Iter: %d, loss increased!!" % (i,)
#
# <ipython-input-3-188e3b6dec0e> in get_cost_and_gradient(self, X, Y)
#     156             fp_contexts.append(fp_context)
#     157
# --> 158         L, O, fp_context = self.layers[-1].fprop_cost(X, Y)
#     159         dLdX = self.layers[-1].bprop_cost(fp_context)
#     160
#
# <ipython-input-3-188e3b6dec0e> in fprop_cost(self, X, Y)
#     104         NS = X.shape[1]
#     105         O = self.compute_probabilities(X)
# --> 106         Cost = -1.0/NS * np.log(O[Y.ravel(), range(NS)]).sum()
#     107         return Cost, O, dict(O=O, X=X, Y=Y)
#     108
#
# KeyboardInterrupt:

# %% [markdown]
# ## Reading data from Fuel
#
# The following cell prepares the data pipeline in fuel. please see SGD template for usage example

# %%
from fuel.datasets.mnist import MNIST
from fuel.transformers import ScaleAndShift, Cast, Flatten, Mapping
from fuel.streams import DataStream
from fuel.schemes import SequentialScheme, ShuffledScheme

MNIST.default_transformers = (
    (ScaleAndShift, [2.0 / 255.0, -1], {'which_sources': 'features'}),
    (Cast, [np.float32], {'which_sources': 'features'}), 
    (Flatten, [], {'which_sources': 'features'}),
    (Mapping, [lambda batch: (b.T for b in batch)], {}) )

mnist_train = MNIST(("train",), subset=slice(None,50000))
#this stream will shuffle the MNIST set and return us batches of 100 examples
mnist_train_stream = DataStream.default_stream(
    mnist_train,
    iteration_scheme=ShuffledScheme(mnist_train.num_examples, 100))
                                               
mnist_validation = MNIST(("train",), subset=slice(50000, None))

# We will use larger portions for testing and validation
# as these dont do a backward pass and reauire less RAM.
mnist_validation_stream = DataStream.default_stream(
    mnist_validation, iteration_scheme=SequentialScheme(mnist_validation.num_examples, 250))
mnist_test = MNIST(("test",))
mnist_test_stream = DataStream.default_stream(
    mnist_test, iteration_scheme=SequentialScheme(mnist_test.num_examples, 250))

# %%
print "The streams return batches containing %s" % (mnist_train_stream.sources,)

print "Each trainin batch consits of a tuple containing:"
for element in next(mnist_train_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
    
print "Validation/test batches consits of tuples containing:"
for element in next(mnist_test_stream.get_epoch_iterator()):
    print " - an array of size %s containing %s" % (element.shape, element.dtype)
# Out:
# The streams return batches containing (u'features', u'targets')
# Each trainin batch consits of a tuple containing:
#  - an array of size (784, 100) containing float32
#  - an array of size (1, 100) containing uint8
# Validation/test batches consits of tuples containing:
#  - an array of size (784, 250) containing float32
#  - an array of size (1, 250) containing uint8

# %% [markdown]
# # Problem 1 [4p]
#
# Implement the following additions to the SGD code below:
# 1. Momentum [2p]
# 2. Learning rate schedule [1p]
# 3. Weight decay [1p]. One way to implement it is to use the functions `net.params` and `net.param_names` to get all parameters whose names are "W" and not "b".

# %%
#
# Please note, the code blow is able to train a SoftMax regression model on mnist to poor results (ca 8%test error), 
# you must improve it
#

from copy import deepcopy

def compute_error_rate(net, stream):
    num_errs = 0.0
    num_examples = 0
    for X, Y in stream.get_epoch_iterator():
        O = net.fprop(X)
        num_errs += (O.argmax(0) != Y).sum()
        num_examples += X.shape[1]
    return num_errs/num_examples

def SGD(net, train_stream, validation_stream, test_stream):
    i=0
    e=0
    
    #initialize momentum variables
    #
    # TODO
    #
    # Hint: you need one valocity matrix for each parameter
    velocities = [np.zeros(P.shape) for P in net.parameters]
    
    best_valid_error_rate = np.inf
    best_params = deepcopy(net.parameters)
    best_params_epoch = 0
    
    train_erros = []
    train_loss = []
    validation_errors = []
    
    number_of_epochs = 3
    patience_expansion = 1.5
    alpha_start = 5e-2
    alpha = alpha_start
    
    try:
        while e<number_of_epochs: #This loop goes over epochs
            e += 1
            #First train on all data from this batch
            for X,Y in train_stream.get_epoch_iterator(): 
                i += 1
                L, O, gradients = net.get_cost_and_gradient(X, Y)
                err_rate = (O.argmax(0) != Y).mean()
                train_loss.append((i,L))
                train_erros.append((i,err_rate))
                if i % 100 == 0:
                    print "At minibatch %d, batch loss %f, batch error rate %f%%" % (i, L, err_rate*100)
                
                #if train_loss[i-1][1] > train_loss[i-2][1]:
                #    alpha *= 1.005
                #else:
                #    alpha *= 0.995
                
                for P, V, G, N in zip(net.parameters, velocities, gradients, net.parameter_names):
                    if N=='W':
                        #pass
                        #
                        # TODO: implement the weight decay addition to gradient
                        #
                        #G += TODO
                        G += 0.001 * P
                    
                    #
                    # TODO: set a learning rate
                    #
                    # Hint, use the iteration counter i
                    # alpha = TODO
                    
                    alpha = alpha_start * (0.995 ** e)
                    
                    #
                    # TODO: set the momentum constant 
                    # 
                    mi = 0.5
                    
                    # epsilon = TODO
                    
                    #
                    # TODO: implement velocity update in momentum
                    #
                    V = mi * V + alpha * G
                    
                    # V[...] = TODO
                    
                    #
                    # TODO: set a more sensible learning rule here,
                    # using your learning rate schedule and momentum
                    #
                    #!!!!! Need to modify the actual parameter here! 
                    P -= V
                    norms = np.linalg.norm(P, axis = 1).reshape( (len(P), 1))
                    div = np.maximum(norms, 1.0)
                    P /= div
                    new_norms = np.linalg.norm(P, axis = 1)
                    assert(np.max(new_norms) <= 1.1)
                    #P -= alpha * G
            # After an epoch compute validation error
            val_error_rate = compute_error_rate(net, validation_stream)
            if val_error_rate < best_valid_error_rate:
                number_of_epochs = np.maximum(number_of_epochs, e * patience_expansion+1)
                best_valid_error_rate = val_error_rate
                best_params = deepcopy(net.parameters)
                best_params_epoch = e
                validation_errors.append((i,val_error_rate))
            print "After epoch %d: valid_err_rate: %f%% currently going ot do %d epochs" %(
                e, val_error_rate, number_of_epochs)
            
    except KeyboardInterrupt:
        print "Setting network parameters from after epoch %d" %(best_params_epoch)
        net.parameters = best_params
        
        subplot(2,1,1)
        train_loss = np.array(train_loss)
        semilogy(train_loss[:,0], train_loss[:,1], label='batch train loss')
        legend()
        
        subplot(2,1,2)
        train_erros = np.array(train_erros)
        plot(train_erros[:,0], train_erros[:,1], label='batch train error rate')
        validation_errors = np.array(validation_errors)
        plot(validation_errors[:,0], validation_errors[:,1], label='validation error rate', color='r')
        ylim(0,0.2)
        legend()

# %% [markdown]
# # Problem 2 [5p]
#
# Tune the following network to reach below 1.9% error rate on
# the validation set. This should result in a test error below 2%. To
# tune the network you will need to:
# 1. choose the number of layers (more than 1, less than 5),
# 2. choose the number of neurons in each layer (more than 100,
#     less than 5000),
# 3. pick proper weight initialization,
# 4. pick proper learning rate schedule (need to decay over time,
#     good range to check on MNIST is about 1e-2 ... 1e-1 at the beginning and
#     half of that after 10000 batches),
# 5. pick a momentum constant (probably a constant one will be OK).

# %%
#
# TODO: pick a network architecture here. The one below is just 
# softmax regression
#

net = FeedForwardNet([
        AffineLayer(784,300),
        ReLULayer(),
        AffineLayer(300,300),
        ReLULayer(),
        AffineLayer(300,300),
        ReLULayer(),
        AffineLayer(300,10),
        SoftMaxLayer()
        ])
SGD(net, mnist_train_stream, mnist_validation_stream, mnist_test_stream)

print "Test error rate: %f" % (compute_error_rate(net, mnist_test_stream), )
# Out:
# At minibatch 100, batch loss 1.464387, batch error rate 47.000000%
# At minibatch 200, batch loss 0.842585, batch error rate 31.000000%
# At minibatch 300, batch loss 0.418796, batch error rate 15.000000%
# At minibatch 400, batch loss 0.404576, batch error rate 14.000000%
# At minibatch 500, batch loss 0.257867, batch error rate 6.000000%
# After epoch 1: valid_err_rate: 0.089500% currently going ot do 3 epochs
# At minibatch 600, batch loss 0.362649, batch error rate 10.000000%
# At minibatch 700, batch loss 0.128186, batch error rate 4.000000%
# At minibatch 800, batch loss 0.458478, batch error rate 19.000000%
# At minibatch 900, batch loss 0.293785, batch error rate 8.000000%
# At minibatch 1000, batch loss 0.299294, batch error rate 10.000000%
# After epoch 2: valid_err_rate: 0.073600% currently going ot do 4 epochs
# At minibatch 1100, batch loss 0.317093, batch error rate 13.000000%
# At minibatch 1200, batch loss 0.206884, batch error rate 5.000000%
# At minibatch 1300, batch loss 0.211350, batch error rate 5.000000%
# At minibatch 1400, batch loss 0.253575, batch error rate 11.000000%
# At minibatch 1500, batch loss 0.204861, batch error rate 4.000000%
# After epoch 3: valid_err_rate: 0.053300% currently going ot do 5 epochs
# At minibatch 1600, batch loss 0.177030, batch error rate 5.000000%
# At minibatch 1700, batch loss 0.142464, batch error rate 5.000000%
# At minibatch 1800, batch loss 0.169882, batch error rate 6.000000%
# At minibatch 1900, batch loss 0.175657, batch error rate 5.000000%
# At minibatch 2000, batch loss 0.171348, batch error rate 6.000000%
# After epoch 4: valid_err_rate: 0.042300% currently going ot do 7 epochs
# At minibatch 2100, batch loss 0.124070, batch error rate 4.000000%
# At minibatch 2200, batch loss 0.133240, batch error rate 6.000000%
# At minibatch 2300, batch loss 0.186073, batch error rate 5.000000%
# At minibatch 2400, batch loss 0.122433, batch error rate 3.000000%
# At minibatch 2500, batch loss 0.293841, batch error rate 7.000000%
# After epoch 5: valid_err_rate: 0.040300% currently going ot do 8 epochs
# At minibatch 2600, batch loss 0.120007, batch error rate 2.000000%
# At minibatch 2700, batch loss 0.127682, batch error rate 7.000000%
# At minibatch 2800, batch loss 0.098180, batch error rate 4.000000%
# At minibatch 2900, batch loss 0.137648, batch error rate 5.000000%
# At minibatch 3000, batch loss 0.048892, batch error rate 1.000000%
# After epoch 6: valid_err_rate: 0.032800% currently going ot do 10 epochs
# At minibatch 3100, batch loss 0.121390, batch error rate 5.000000%
# At minibatch 3200, batch loss 0.069401, batch error rate 2.000000%
# At minibatch 3300, batch loss 0.094705, batch error rate 3.000000%
# At minibatch 3400, batch loss 0.070887, batch error rate 3.000000%
# At minibatch 3500, batch loss 0.120245, batch error rate 6.000000%
# After epoch 7: valid_err_rate: 0.036800% currently going ot do 10 epochs
# At minibatch 3600, batch loss 0.099074, batch error rate 3.000000%
# At minibatch 3700, batch loss 0.083516, batch error rate 2.000000%
# At minibatch 3800, batch loss 0.131000, batch error rate 1.000000%
# At minibatch 3900, batch loss 0.146900, batch error rate 4.000000%
# At minibatch 4000, batch loss 0.140841, batch error rate 5.000000%
# After epoch 8: valid_err_rate: 0.034200% currently going ot do 10 epochs
# At minibatch 4100, batch loss 0.035970, batch error rate 1.000000%
# At minibatch 4200, batch loss 0.082454, batch error rate 3.000000%
# At minibatch 4300, batch loss 0.073365, batch error rate 1.000000%
# At minibatch 4400, batch loss 0.052667, batch error rate 1.000000%
# At minibatch 4500, batch loss 0.136224, batch error rate 4.000000%
# After epoch 9: valid_err_rate: 0.032100% currently going ot do 14 epochs
# At minibatch 4600, batch loss 0.184100, batch error rate 3.000000%
# At minibatch 4700, batch loss 0.083997, batch error rate 2.000000%
# At minibatch 4800, batch loss 0.101849, batch error rate 4.000000%
# At minibatch 4900, batch loss 0.054930, batch error rate 2.000000%
# At minibatch 5000, batch loss 0.072710, batch error rate 0.000000%
# After epoch 10: valid_err_rate: 0.024300% currently going ot do 16 epochs
# At minibatch 5100, batch loss 0.072395, batch error rate 3.000000%
# At minibatch 5200, batch loss 0.051374, batch error rate 1.000000%
# At minibatch 5300, batch loss 0.081140, batch error rate 3.000000%
# At minibatch 5400, batch loss 0.041198, batch error rate 1.000000%
# At minibatch 5500, batch loss 0.047947, batch error rate 1.000000%
# After epoch 11: valid_err_rate: 0.025500% currently going ot do 16 epochs
# At minibatch 5600, batch loss 0.070122, batch error rate 2.000000%
# At minibatch 5700, batch loss 0.040078, batch error rate 1.000000%
# At minibatch 5800, batch loss 0.047244, batch error rate 1.000000%
# At minibatch 5900, batch loss 0.032656, batch error rate 0.000000%
# At minibatch 6000, batch loss 0.036701, batch error rate 1.000000%
# After epoch 12: valid_err_rate: 0.027500% currently going ot do 16 epochs
# At minibatch 6100, batch loss 0.022515, batch error rate 0.000000%
# At minibatch 6200, batch loss 0.070567, batch error rate 2.000000%
# At minibatch 6300, batch loss 0.089660, batch error rate 2.000000%
# At minibatch 6400, batch loss 0.097251, batch error rate 2.000000%
# At minibatch 6500, batch loss 0.021232, batch error rate 0.000000%
# After epoch 13: valid_err_rate: 0.023000% currently going ot do 20 epochs
# At minibatch 6600, batch loss 0.044255, batch error rate 1.000000%
# At minibatch 6700, batch loss 0.040318, batch error rate 0.000000%
# At minibatch 6800, batch loss 0.038701, batch error rate 1.000000%
# At minibatch 6900, batch loss 0.089196, batch error rate 3.000000%
# At minibatch 7000, batch loss 0.052447, batch error rate 1.000000%
# After epoch 14: valid_err_rate: 0.023500% currently going ot do 20 epochs
# At minibatch 7100, batch loss 0.041639, batch error rate 2.000000%
# At minibatch 7200, batch loss 0.017096, batch error rate 0.000000%
# At minibatch 7300, batch loss 0.017303, batch error rate 0.000000%
# At minibatch 7400, batch loss 0.052290, batch error rate 3.000000%
# At minibatch 7500, batch loss 0.187341, batch error rate 4.000000%
# After epoch 15: valid_err_rate: 0.027900% currently going ot do 20 epochs
# At minibatch 7600, batch loss 0.032814, batch error rate 2.000000%
# At minibatch 7700, batch loss 0.034145, batch error rate 1.000000%
# At minibatch 7800, batch loss 0.102944, batch error rate 1.000000%
# At minibatch 7900, batch loss 0.103549, batch error rate 4.000000%
# At minibatch 8000, batch loss 0.050357, batch error rate 1.000000%
# After epoch 16: valid_err_rate: 0.024800% currently going ot do 20 epochs
# At minibatch 8100, batch loss 0.098533, batch error rate 5.000000%
# At minibatch 8200, batch loss 0.022208, batch error rate 1.000000%
# At minibatch 8300, batch loss 0.011904, batch error rate 0.000000%
# At minibatch 8400, batch loss 0.018755, batch error rate 0.000000%
# At minibatch 8500, batch loss 0.043823, batch error rate 1.000000%
# After epoch 17: valid_err_rate: 0.022700% currently going ot do 26 epochs
# At minibatch 8600, batch loss 0.075139, batch error rate 3.000000%
# At minibatch 8700, batch loss 0.050288, batch error rate 2.000000%
# At minibatch 8800, batch loss 0.090949, batch error rate 4.000000%
# At minibatch 8900, batch loss 0.042327, batch error rate 1.000000%
# At minibatch 9000, batch loss 0.103283, batch error rate 3.000000%
# After epoch 18: valid_err_rate: 0.065900% currently going ot do 26 epochs
# At minibatch 9100, batch loss 0.064839, batch error rate 3.000000%
# At minibatch 9200, batch loss 0.047734, batch error rate 2.000000%
# At minibatch 9300, batch loss 0.038141, batch error rate 1.000000%
# At minibatch 9400, batch loss 0.032857, batch error rate 1.000000%
# At minibatch 9500, batch loss 0.110233, batch error rate 1.000000%
# After epoch 19: valid_err_rate: 0.021500% currently going ot do 29 epochs
# At minibatch 9600, batch loss 0.034630, batch error rate 2.000000%
# At minibatch 9700, batch loss 0.015808, batch error rate 0.000000%
# At minibatch 9800, batch loss 0.030081, batch error rate 0.000000%
# At minibatch 9900, batch loss 0.013510, batch error rate 0.000000%
# At minibatch 10000, batch loss 0.017104, batch error rate 1.000000%
# After epoch 20: valid_err_rate: 0.022600% currently going ot do 29 epochs
# At minibatch 10100, batch loss 0.013891, batch error rate 0.000000%
# At minibatch 10200, batch loss 0.008674, batch error rate 0.000000%
# At minibatch 10300, batch loss 0.039577, batch error rate 1.000000%
# At minibatch 10400, batch loss 0.046615, batch error rate 2.000000%
# At minibatch 10500, batch loss 0.008274, batch error rate 0.000000%
# After epoch 21: valid_err_rate: 0.024200% currently going ot do 29 epochs
# At minibatch 10600, batch loss 0.038925, batch error rate 1.000000%
# At minibatch 10700, batch loss 0.026542, batch error rate 1.000000%
# At minibatch 10800, batch loss 0.055763, batch error rate 2.000000%
# At minibatch 10900, batch loss 0.067175, batch error rate 1.000000%
# At minibatch 11000, batch loss 0.012493, batch error rate 0.000000%
# After epoch 22: valid_err_rate: 0.021800% currently going ot do 29 epochs
# At minibatch 11100, batch loss 0.053390, batch error rate 2.000000%
# At minibatch 11200, batch loss 0.048609, batch error rate 1.000000%
# At minibatch 11300, batch loss 0.035285, batch error rate 1.000000%
# At minibatch 11400, batch loss 0.025484, batch error rate 1.000000%
# At minibatch 11500, batch loss 0.055173, batch error rate 2.000000%
# After epoch 23: valid_err_rate: 0.020600% currently going ot do 35 epochs
# At minibatch 11600, batch loss 0.023250, batch error rate 0.000000%
# At minibatch 11700, batch loss 0.046381, batch error rate 1.000000%
# At minibatch 11800, batch loss 0.057951, batch error rate 1.000000%
# At minibatch 11900, batch loss 0.011045, batch error rate 0.000000%
# At minibatch 12000, batch loss 0.024048, batch error rate 1.000000%
# After epoch 24: valid_err_rate: 0.022300% currently going ot do 35 epochs
# At minibatch 12100, batch loss 0.011190, batch error rate 0.000000%
# At minibatch 12200, batch loss 0.035923, batch error rate 1.000000%
# At minibatch 12300, batch loss 0.013850, batch error rate 0.000000%
# At minibatch 12400, batch loss 0.019708, batch error rate 0.000000%
# At minibatch 12500, batch loss 0.021473, batch error rate 0.000000%
# After epoch 25: valid_err_rate: 0.021300% currently going ot do 35 epochs
# At minibatch 12600, batch loss 0.033369, batch error rate 1.000000%
# At minibatch 12700, batch loss 0.038205, batch error rate 1.000000%
# At minibatch 12800, batch loss 0.023121, batch error rate 1.000000%
# At minibatch 12900, batch loss 0.050476, batch error rate 2.000000%
# At minibatch 13000, batch loss 0.028467, batch error rate 2.000000%
# After epoch 26: valid_err_rate: 0.021200% currently going ot do 35 epochs
# At minibatch 13100, batch loss 0.013890, batch error rate 0.000000%
# At minibatch 13200, batch loss 0.010296, batch error rate 0.000000%
# At minibatch 13300, batch loss 0.024727, batch error rate 0.000000%
# At minibatch 13400, batch loss 0.008347, batch error rate 0.000000%
# At minibatch 13500, batch loss 0.009597, batch error rate 0.000000%
# After epoch 27: valid_err_rate: 0.021700% currently going ot do 35 epochs
# At minibatch 13600, batch loss 0.011678, batch error rate 0.000000%
# At minibatch 13700, batch loss 0.031087, batch error rate 1.000000%
# At minibatch 13800, batch loss 0.020022, batch error rate 1.000000%
# At minibatch 13900, batch loss 0.019489, batch error rate 0.000000%
# At minibatch 14000, batch loss 0.021781, batch error rate 0.000000%
# After epoch 28: valid_err_rate: 0.019600% currently going ot do 43 epochs
# At minibatch 14100, batch loss 0.011450, batch error rate 0.000000%
# At minibatch 14200, batch loss 0.057228, batch error rate 2.000000%
# At minibatch 14300, batch loss 0.008261, batch error rate 0.000000%
# At minibatch 14400, batch loss 0.014282, batch error rate 0.000000%
# At minibatch 14500, batch loss 0.017440, batch error rate 0.000000%
# After epoch 29: valid_err_rate: 0.021000% currently going ot do 43 epochs
# At minibatch 14600, batch loss 0.014786, batch error rate 0.000000%
# At minibatch 14700, batch loss 0.020905, batch error rate 1.000000%
# At minibatch 14800, batch loss 0.017776, batch error rate 0.000000%
# At minibatch 14900, batch loss 0.006461, batch error rate 0.000000%
# At minibatch 15000, batch loss 0.014713, batch error rate 0.000000%
# After epoch 30: valid_err_rate: 0.019300% currently going ot do 46 epochs
# At minibatch 15100, batch loss 0.009250, batch error rate 0.000000%
# At minibatch 15200, batch loss 0.025315, batch error rate 1.000000%
# At minibatch 15300, batch loss 0.018155, batch error rate 0.000000%
# At minibatch 15400, batch loss 0.020716, batch error rate 0.000000%
# At minibatch 15500, batch loss 0.010795, batch error rate 0.000000%
# After epoch 31: valid_err_rate: 0.022100% currently going ot do 46 epochs
# At minibatch 15600, batch loss 0.027962, batch error rate 0.000000%
# At minibatch 15700, batch loss 0.020788, batch error rate 1.000000%
# At minibatch 15800, batch loss 0.014425, batch error rate 0.000000%
# At minibatch 15900, batch loss 0.011184, batch error rate 0.000000%
# At minibatch 16000, batch loss 0.007163, batch error rate 0.000000%
# After epoch 32: valid_err_rate: 0.019500% currently going ot do 46 epochs
# At minibatch 16100, batch loss 0.017881, batch error rate 0.000000%
# At minibatch 16200, batch loss 0.032889, batch error rate 1.000000%
# At minibatch 16300, batch loss 0.025759, batch error rate 1.000000%
# At minibatch 16400, batch loss 0.020989, batch error rate 0.000000%
# At minibatch 16500, batch loss 0.019096, batch error rate 0.000000%
# After epoch 33: valid_err_rate: 0.018900% currently going ot do 50 epochs
# At minibatch 16600, batch loss 0.019354, batch error rate 0.000000%
# At minibatch 16700, batch loss 0.014963, batch error rate 0.000000%
# At minibatch 16800, batch loss 0.010727, batch error rate 0.000000%
# At minibatch 16900, batch loss 0.021908, batch error rate 0.000000%
# At minibatch 17000, batch loss 0.014516, batch error rate 0.000000%
# After epoch 34: valid_err_rate: 0.020600% currently going ot do 50 epochs
# At minibatch 17100, batch loss 0.015885, batch error rate 0.000000%
# At minibatch 17200, batch loss 0.042458, batch error rate 2.000000%
# At minibatch 17300, batch loss 0.019578, batch error rate 0.000000%
# At minibatch 17400, batch loss 0.010103, batch error rate 0.000000%
# At minibatch 17500, batch loss 0.011209, batch error rate 0.000000%
# After epoch 35: valid_err_rate: 0.020200% currently going ot do 50 epochs
# At minibatch 17600, batch loss 0.012805, batch error rate 0.000000%
# At minibatch 17700, batch loss 0.004357, batch error rate 0.000000%
# At minibatch 17800, batch loss 0.066697, batch error rate 1.000000%
# At minibatch 17900, batch loss 0.026315, batch error rate 1.000000%
# At minibatch 18000, batch loss 0.031977, batch error rate 1.000000%
# After epoch 36: valid_err_rate: 0.019600% currently going ot do 50 epochs
# At minibatch 18100, batch loss 0.023770, batch error rate 1.000000%
# At minibatch 18200, batch loss 0.013298, batch error rate 0.000000%
# At minibatch 18300, batch loss 0.014381, batch error rate 0.000000%
# At minibatch 18400, batch loss 0.018745, batch error rate 0.000000%
# At minibatch 18500, batch loss 0.024993, batch error rate 1.000000%
# After epoch 37: valid_err_rate: 0.024500% currently going ot do 50 epochs
# At minibatch 18600, batch loss 0.010753, batch error rate 0.000000%
# At minibatch 18700, batch loss 0.008503, batch error rate 0.000000%
# At minibatch 18800, batch loss 0.023589, batch error rate 0.000000%
# At minibatch 18900, batch loss 0.022979, batch error rate 1.000000%
# At minibatch 19000, batch loss 0.005049, batch error rate 0.000000%
# After epoch 38: valid_err_rate: 0.018500% currently going ot do 58 epochs
# At minibatch 19100, batch loss 0.011195, batch error rate 0.000000%
# At minibatch 19200, batch loss 0.024939, batch error rate 1.000000%
# At minibatch 19300, batch loss 0.012819, batch error rate 0.000000%
# At minibatch 19400, batch loss 0.025852, batch error rate 1.000000%
# At minibatch 19500, batch loss 0.062184, batch error rate 1.000000%
# After epoch 39: valid_err_rate: 0.025200% currently going ot do 58 epochs
# At minibatch 19600, batch loss 0.013800, batch error rate 0.000000%
# At minibatch 19700, batch loss 0.006494, batch error rate 0.000000%
# At minibatch 19800, batch loss 0.044899, batch error rate 2.000000%
# At minibatch 19900, batch loss 0.011198, batch error rate 0.000000%
# At minibatch 20000, batch loss 0.006491, batch error rate 0.000000%
# After epoch 40: valid_err_rate: 0.018400% currently going ot do 61 epochs
# At minibatch 20100, batch loss 0.015726, batch error rate 0.000000%
# At minibatch 20200, batch loss 0.012288, batch error rate 0.000000%
# At minibatch 20300, batch loss 0.012726, batch error rate 0.000000%
# Setting network parameters from after epoch 40
# Test error rate: 0.020200

# %%
compute_error_rate(net, mnist_test_stream)
# Out:
# 0.0202

# %% [markdown]
# # Problem 3 [2p bonus]
#
# Implement norm constraints, i.e. limit the total
# norm of connections incoming to a neuron. In our case, this
# corresponds to clipping the norm of *rows* of weight
# matrices. An easy way of implementing it is to make a gradient
# step, then look at the norm of rows and scale down those that are
# over the threshold (this technique is called "projected gradient descent").

# %%
P = np.array([ [2, 2, 2], [0.3, 0.3, 0.3]])
print (P)
norms = np.linalg.norm(P, axis = 1).reshape( (len(P), 1))
print (norms)
div = np.maximum(norms, 1.0)
print (div)
P /= div
print (P)
# Out:
# [[ 2.   2.   2. ]
#  [ 0.3  0.3  0.3]]
# [[ 3.46410162]
#  [ 0.51961524]]
# [[ 3.46410162]
#  [ 1.        ]]
# [[ 0.57735027  0.57735027  0.57735027]
#  [ 0.3         0.3         0.3       ]]

# %%
#
# TODO: pick a network architecture here. The one below is just 
# softmax regression
#

net = FeedForwardNet([
        AffineLayer(784,300),
        ReLULayer(),
        AffineLayer(300,300),
        ReLULayer(),
        AffineLayer(300,300),
        ReLULayer(),
        AffineLayer(300,10),
        SoftMaxLayer()
        ])
SGD(net, mnist_train_stream, mnist_validation_stream, mnist_test_stream)

print "Test error rate: %f" % (compute_error_rate(net, mnist_test_stream), )
# Out:
# At minibatch 100, batch loss 1.266658, batch error rate 41.000000%
# At minibatch 200, batch loss 0.608795, batch error rate 20.000000%
# At minibatch 300, batch loss 0.412981, batch error rate 12.000000%
# At minibatch 400, batch loss 0.408079, batch error rate 10.000000%
# At minibatch 500, batch loss 0.338131, batch error rate 9.000000%
# After epoch 1: valid_err_rate: 0.085000% currently going ot do 3 epochs
# At minibatch 600, batch loss 0.268459, batch error rate 7.000000%
# At minibatch 700, batch loss 0.301950, batch error rate 8.000000%
# At minibatch 800, batch loss 0.271272, batch error rate 8.000000%
# At minibatch 900, batch loss 0.237138, batch error rate 6.000000%
# At minibatch 1000, batch loss 0.225935, batch error rate 5.000000%
# After epoch 2: valid_err_rate: 0.063700% currently going ot do 4 epochs
# At minibatch 1100, batch loss 0.261682, batch error rate 9.000000%
# At minibatch 1200, batch loss 0.377643, batch error rate 12.000000%
# At minibatch 1300, batch loss 0.242199, batch error rate 9.000000%
# At minibatch 1400, batch loss 0.148790, batch error rate 2.000000%
# At minibatch 1500, batch loss 0.179033, batch error rate 6.000000%
# After epoch 3: valid_err_rate: 0.048700% currently going ot do 5 epochs
# At minibatch 1600, batch loss 0.221858, batch error rate 10.000000%
# At minibatch 1700, batch loss 0.253323, batch error rate 6.000000%
# At minibatch 1800, batch loss 0.187053, batch error rate 7.000000%
# At minibatch 1900, batch loss 0.124221, batch error rate 4.000000%
# At minibatch 2000, batch loss 0.131843, batch error rate 5.000000%
# After epoch 4: valid_err_rate: 0.048500% currently going ot do 7 epochs
# At minibatch 2100, batch loss 0.173402, batch error rate 4.000000%
# At minibatch 2200, batch loss 0.145062, batch error rate 5.000000%
# At minibatch 2300, batch loss 0.216915, batch error rate 7.000000%
# At minibatch 2400, batch loss 0.242372, batch error rate 6.000000%
# At minibatch 2500, batch loss 0.190321, batch error rate 6.000000%
# After epoch 5: valid_err_rate: 0.039100% currently going ot do 8 epochs
# At minibatch 2600, batch loss 0.079391, batch error rate 2.000000%
# At minibatch 2700, batch loss 0.059471, batch error rate 1.000000%
# At minibatch 2800, batch loss 0.123087, batch error rate 2.000000%
# At minibatch 2900, batch loss 0.124558, batch error rate 5.000000%
# At minibatch 3000, batch loss 0.143405, batch error rate 5.000000%
# After epoch 6: valid_err_rate: 0.036800% currently going ot do 10 epochs
# At minibatch 3100, batch loss 0.096870, batch error rate 2.000000%
# At minibatch 3200, batch loss 0.178805, batch error rate 5.000000%
# At minibatch 3300, batch loss 0.061835, batch error rate 3.000000%
# At minibatch 3400, batch loss 0.062346, batch error rate 2.000000%
# At minibatch 3500, batch loss 0.133972, batch error rate 7.000000%
# After epoch 7: valid_err_rate: 0.036100% currently going ot do 11 epochs
# At minibatch 3600, batch loss 0.158082, batch error rate 6.000000%
# At minibatch 3700, batch loss 0.085483, batch error rate 2.000000%
# At minibatch 3800, batch loss 0.088798, batch error rate 2.000000%
# At minibatch 3900, batch loss 0.023577, batch error rate 0.000000%
# At minibatch 4000, batch loss 0.178027, batch error rate 5.000000%
# After epoch 8: valid_err_rate: 0.032100% currently going ot do 13 epochs
# At minibatch 4100, batch loss 0.073462, batch error rate 2.000000%
# At minibatch 4200, batch loss 0.128910, batch error rate 5.000000%
# At minibatch 4300, batch loss 0.051952, batch error rate 1.000000%
# At minibatch 4400, batch loss 0.177296, batch error rate 5.000000%
# At minibatch 4500, batch loss 0.120563, batch error rate 3.000000%
# After epoch 9: valid_err_rate: 0.032400% currently going ot do 13 epochs
# At minibatch 4600, batch loss 0.044301, batch error rate 1.000000%
# At minibatch 4700, batch loss 0.128285, batch error rate 5.000000%
# At minibatch 4800, batch loss 0.037697, batch error rate 0.000000%
# At minibatch 4900, batch loss 0.119246, batch error rate 4.000000%
# At minibatch 5000, batch loss 0.057919, batch error rate 1.000000%
# After epoch 10: valid_err_rate: 0.027100% currently going ot do 16 epochs
# At minibatch 5100, batch loss 0.055337, batch error rate 2.000000%
# At minibatch 5200, batch loss 0.032438, batch error rate 0.000000%
# At minibatch 5300, batch loss 0.049149, batch error rate 1.000000%
# At minibatch 5400, batch loss 0.050781, batch error rate 1.000000%
# At minibatch 5500, batch loss 0.052016, batch error rate 1.000000%
# After epoch 11: valid_err_rate: 0.027000% currently going ot do 17 epochs
# At minibatch 5600, batch loss 0.078201, batch error rate 1.000000%
# At minibatch 5700, batch loss 0.036501, batch error rate 0.000000%
# At minibatch 5800, batch loss 0.182773, batch error rate 4.000000%
# At minibatch 5900, batch loss 0.071812, batch error rate 2.000000%
# At minibatch 6000, batch loss 0.088681, batch error rate 3.000000%
# After epoch 12: valid_err_rate: 0.025500% currently going ot do 19 epochs
# At minibatch 6100, batch loss 0.104456, batch error rate 2.000000%
# At minibatch 6200, batch loss 0.078065, batch error rate 1.000000%
# At minibatch 6300, batch loss 0.084010, batch error rate 3.000000%
# At minibatch 6400, batch loss 0.087106, batch error rate 1.000000%
# At minibatch 6500, batch loss 0.081220, batch error rate 3.000000%
# After epoch 13: valid_err_rate: 0.024200% currently going ot do 20 epochs
# At minibatch 6600, batch loss 0.097156, batch error rate 3.000000%
# At minibatch 6700, batch loss 0.035712, batch error rate 1.000000%
# At minibatch 6800, batch loss 0.083218, batch error rate 1.000000%
# At minibatch 6900, batch loss 0.026843, batch error rate 1.000000%
# At minibatch 7000, batch loss 0.039326, batch error rate 0.000000%
# After epoch 14: valid_err_rate: 0.027300% currently going ot do 20 epochs
# At minibatch 7100, batch loss 0.084098, batch error rate 2.000000%
# At minibatch 7200, batch loss 0.033159, batch error rate 0.000000%
# At minibatch 7300, batch loss 0.062494, batch error rate 2.000000%
# At minibatch 7400, batch loss 0.078928, batch error rate 3.000000%
# At minibatch 7500, batch loss 0.053474, batch error rate 1.000000%
# After epoch 15: valid_err_rate: 0.024400% currently going ot do 20 epochs
# At minibatch 7600, batch loss 0.071451, batch error rate 2.000000%
# At minibatch 7700, batch loss 0.049058, batch error rate 2.000000%
# At minibatch 7800, batch loss 0.038961, batch error rate 1.000000%
# At minibatch 7900, batch loss 0.078378, batch error rate 2.000000%
# At minibatch 8000, batch loss 0.026571, batch error rate 0.000000%
# After epoch 16: valid_err_rate: 0.025600% currently going ot do 20 epochs
# At minibatch 8100, batch loss 0.051011, batch error rate 2.000000%
# At minibatch 8200, batch loss 0.024772, batch error rate 1.000000%
# At minibatch 8300, batch loss 0.084887, batch error rate 3.000000%
# At minibatch 8400, batch loss 0.044895, batch error rate 1.000000%
# At minibatch 8500, batch loss 0.035140, batch error rate 1.000000%
# After epoch 17: valid_err_rate: 0.024100% currently going ot do 26 epochs
# At minibatch 8600, batch loss 0.067218, batch error rate 1.000000%
# At minibatch 8700, batch loss 0.087595, batch error rate 3.000000%
# At minibatch 8800, batch loss 0.081117, batch error rate 3.000000%
# At minibatch 8900, batch loss 0.035334, batch error rate 1.000000%
# At minibatch 9000, batch loss 0.026436, batch error rate 1.000000%
# After epoch 18: valid_err_rate: 0.022100% currently going ot do 28 epochs
# At minibatch 9100, batch loss 0.112088, batch error rate 2.000000%
# At minibatch 9200, batch loss 0.104390, batch error rate 3.000000%
# At minibatch 9300, batch loss 0.054320, batch error rate 2.000000%
# At minibatch 9400, batch loss 0.298940, batch error rate 9.000000%
# At minibatch 9500, batch loss 0.054325, batch error rate 2.000000%
# After epoch 19: valid_err_rate: 0.023500% currently going ot do 28 epochs
# At minibatch 9600, batch loss 0.133870, batch error rate 6.000000%
# At minibatch 9700, batch loss 0.051360, batch error rate 2.000000%
# At minibatch 9800, batch loss 0.160061, batch error rate 4.000000%
# At minibatch 9900, batch loss 0.038542, batch error rate 1.000000%
# At minibatch 10000, batch loss 0.027356, batch error rate 0.000000%
# After epoch 20: valid_err_rate: 0.021000% currently going ot do 31 epochs
# At minibatch 10100, batch loss 0.102004, batch error rate 3.000000%
# At minibatch 10200, batch loss 0.018912, batch error rate 0.000000%
# At minibatch 10300, batch loss 0.082393, batch error rate 1.000000%
# At minibatch 10400, batch loss 0.061484, batch error rate 2.000000%
# At minibatch 10500, batch loss 0.031550, batch error rate 1.000000%
# After epoch 21: valid_err_rate: 0.023500% currently going ot do 31 epochs
# At minibatch 10600, batch loss 0.045252, batch error rate 2.000000%
# At minibatch 10700, batch loss 0.073691, batch error rate 2.000000%
# At minibatch 10800, batch loss 0.059398, batch error rate 2.000000%
# At minibatch 10900, batch loss 0.028242, batch error rate 0.000000%
# At minibatch 11000, batch loss 0.050050, batch error rate 2.000000%
# After epoch 22: valid_err_rate: 0.020700% currently going ot do 34 epochs
# At minibatch 11100, batch loss 0.100192, batch error rate 4.000000%
# At minibatch 11200, batch loss 0.020930, batch error rate 1.000000%
# At minibatch 11300, batch loss 0.034670, batch error rate 1.000000%
# At minibatch 11400, batch loss 0.022369, batch error rate 0.000000%
# At minibatch 11500, batch loss 0.030067, batch error rate 1.000000%
# After epoch 23: valid_err_rate: 0.020300% currently going ot do 35 epochs
# At minibatch 11600, batch loss 0.035274, batch error rate 1.000000%
# At minibatch 11700, batch loss 0.051627, batch error rate 2.000000%
# At minibatch 11800, batch loss 0.020982, batch error rate 0.000000%
# At minibatch 11900, batch loss 0.019111, batch error rate 0.000000%
# At minibatch 12000, batch loss 0.065570, batch error rate 1.000000%
# After epoch 24: valid_err_rate: 0.020900% currently going ot do 35 epochs
# At minibatch 12100, batch loss 0.012798, batch error rate 0.000000%
# At minibatch 12200, batch loss 0.029419, batch error rate 1.000000%
# At minibatch 12300, batch loss 0.031209, batch error rate 1.000000%
# At minibatch 12400, batch loss 0.056342, batch error rate 2.000000%
# At minibatch 12500, batch loss 0.024585, batch error rate 0.000000%
# After epoch 25: valid_err_rate: 0.021600% currently going ot do 35 epochs
# At minibatch 12600, batch loss 0.016248, batch error rate 0.000000%
# At minibatch 12700, batch loss 0.050343, batch error rate 2.000000%
# At minibatch 12800, batch loss 0.028138, batch error rate 1.000000%
# At minibatch 12900, batch loss 0.043243, batch error rate 2.000000%
# At minibatch 13000, batch loss 0.124583, batch error rate 4.000000%
# After epoch 26: valid_err_rate: 0.023600% currently going ot do 35 epochs
# At minibatch 13100, batch loss 0.027547, batch error rate 2.000000%
# At minibatch 13200, batch loss 0.028259, batch error rate 0.000000%
# At minibatch 13300, batch loss 0.036586, batch error rate 1.000000%
# At minibatch 13400, batch loss 0.036061, batch error rate 1.000000%
# At minibatch 13500, batch loss 0.020487, batch error rate 0.000000%
# After epoch 27: valid_err_rate: 0.019000% currently going ot do 41 epochs
# At minibatch 13600, batch loss 0.041537, batch error rate 1.000000%
# At minibatch 13700, batch loss 0.033697, batch error rate 1.000000%
# At minibatch 13800, batch loss 0.034298, batch error rate 1.000000%
# At minibatch 13900, batch loss 0.088028, batch error rate 3.000000%
# At minibatch 14000, batch loss 0.022965, batch error rate 0.000000%
# After epoch 28: valid_err_rate: 0.024300% currently going ot do 41 epochs
# At minibatch 14100, batch loss 0.039715, batch error rate 0.000000%
# At minibatch 14200, batch loss 0.093273, batch error rate 4.000000%
# At minibatch 14300, batch loss 0.032162, batch error rate 0.000000%
# At minibatch 14400, batch loss 0.074009, batch error rate 3.000000%
# At minibatch 14500, batch loss 0.067236, batch error rate 1.000000%
# After epoch 29: valid_err_rate: 0.020700% currently going ot do 41 epochs
# At minibatch 14600, batch loss 0.019895, batch error rate 0.000000%
# At minibatch 14700, batch loss 0.053526, batch error rate 2.000000%
# At minibatch 14800, batch loss 0.037267, batch error rate 1.000000%
# At minibatch 14900, batch loss 0.035793, batch error rate 1.000000%
# At minibatch 15000, batch loss 0.024364, batch error rate 0.000000%
# After epoch 30: valid_err_rate: 0.018400% currently going ot do 46 epochs
# At minibatch 15100, batch loss 0.041130, batch error rate 2.000000%
# At minibatch 15200, batch loss 0.026559, batch error rate 1.000000%
# At minibatch 15300, batch loss 0.013299, batch error rate 0.000000%
# At minibatch 15400, batch loss 0.017163, batch error rate 0.000000%
# At minibatch 15500, batch loss 0.018473, batch error rate 0.000000%
# After epoch 31: valid_err_rate: 0.021600% currently going ot do 46 epochs
# At minibatch 15600, batch loss 0.038551, batch error rate 1.000000%
# At minibatch 15700, batch loss 0.019744, batch error rate 1.000000%
# At minibatch 15800, batch loss 0.055477, batch error rate 2.000000%
# At minibatch 15900, batch loss 0.023885, batch error rate 0.000000%
# At minibatch 16000, batch loss 0.015498, batch error rate 0.000000%
# After epoch 32: valid_err_rate: 0.019600% currently going ot do 46 epochs
# At minibatch 16100, batch loss 0.030877, batch error rate 1.000000%
# At minibatch 16200, batch loss 0.028831, batch error rate 1.000000%
# At minibatch 16300, batch loss 0.040090, batch error rate 0.000000%
# At minibatch 16400, batch loss 0.031604, batch error rate 0.000000%
# At minibatch 16500, batch loss 0.019356, batch error rate 0.000000%
# After epoch 33: valid_err_rate: 0.017800% currently going ot do 50 epochs
# At minibatch 16600, batch loss 0.021723, batch error rate 0.000000%
# At minibatch 16700, batch loss 0.037974, batch error rate 2.000000%
# At minibatch 16800, batch loss 0.028446, batch error rate 1.000000%
# At minibatch 16900, batch loss 0.014583, batch error rate 0.000000%
# At minibatch 17000, batch loss 0.053472, batch error rate 2.000000%
# After epoch 34: valid_err_rate: 0.021400% currently going ot do 50 epochs
# At minibatch 17100, batch loss 0.025720, batch error rate 0.000000%
# At minibatch 17200, batch loss 0.021404, batch error rate 0.000000%
# At minibatch 17300, batch loss 0.018019, batch error rate 0.000000%
# At minibatch 17400, batch loss 0.041550, batch error rate 2.000000%
# At minibatch 17500, batch loss 0.040611, batch error rate 2.000000%
# After epoch 35: valid_err_rate: 0.020000% currently going ot do 50 epochs
# At minibatch 17600, batch loss 0.033948, batch error rate 1.000000%
# At minibatch 17700, batch loss 0.020498, batch error rate 1.000000%
# At minibatch 17800, batch loss 0.016636, batch error rate 0.000000%
# At minibatch 17900, batch loss 0.010244, batch error rate 0.000000%
# At minibatch 18000, batch loss 0.059139, batch error rate 1.000000%
# After epoch 36: valid_err_rate: 0.019000% currently going ot do 50 epochs
# At minibatch 18100, batch loss 0.040048, batch error rate 2.000000%
# At minibatch 18200, batch loss 0.013645, batch error rate 0.000000%
# At minibatch 18300, batch loss 0.043753, batch error rate 1.000000%
# At minibatch 18400, batch loss 0.061819, batch error rate 3.000000%
# At minibatch 18500, batch loss 0.027963, batch error rate 1.000000%
# After epoch 37: valid_err_rate: 0.020200% currently going ot do 50 epochs
# At minibatch 18600, batch loss 0.043689, batch error rate 1.000000%
# At minibatch 18700, batch loss 0.029757, batch error rate 2.000000%
# At minibatch 18800, batch loss 0.084898, batch error rate 2.000000%
# At minibatch 18900, batch loss 0.034043, batch error rate 1.000000%
# At minibatch 19000, batch loss 0.014543, batch error rate 0.000000%
# After epoch 38: valid_err_rate: 0.018900% currently going ot do 50 epochs
# At minibatch 19100, batch loss 0.027285, batch error rate 0.000000%
# At minibatch 19200, batch loss 0.024275, batch error rate 1.000000%
# At minibatch 19300, batch loss 0.034835, batch error rate 0.000000%
# At minibatch 19400, batch loss 0.013469, batch error rate 0.000000%
# At minibatch 19500, batch loss 0.063482, batch error rate 1.000000%
# After epoch 39: valid_err_rate: 0.026200% currently going ot do 50 epochs
# At minibatch 19600, batch loss 0.009483, batch error rate 0.000000%
# At minibatch 19700, batch loss 0.048830, batch error rate 2.000000%
# At minibatch 19800, batch loss 0.015109, batch error rate 0.000000%
# At minibatch 19900, batch loss 0.014703, batch error rate 0.000000%
# At minibatch 20000, batch loss 0.011431, batch error rate 0.000000%
# After epoch 40: valid_err_rate: 0.017700% currently going ot do 61 epochs
# At minibatch 20100, batch loss 0.027982, batch error rate 1.000000%
# At minibatch 20200, batch loss 0.019877, batch error rate 0.000000%
# At minibatch 20300, batch loss 0.037927, batch error rate 1.000000%
# At minibatch 20400, batch loss 0.026272, batch error rate 0.000000%
# At minibatch 20500, batch loss 0.017559, batch error rate 0.000000%
# After epoch 41: valid_err_rate: 0.019300% currently going ot do 61 epochs
# At minibatch 20600, batch loss 0.027609, batch error rate 0.000000%
# At minibatch 20700, batch loss 0.017423, batch error rate 0.000000%
# At minibatch 20800, batch loss 0.023205, batch error rate 0.000000%
# Setting network parameters from after epoch 40
# Test error rate: 0.019000

# %%
compute_error_rate(net, mnist_test_stream)
# Out:
# 0.019

# %% [markdown]
# # Problem 7 list 3 [1p bonus]
#
#  While on a walk, you notice that a locomotive has the serial number
#   50. Assuming that all locomotives used by PKP (the Polish railroad
#   operator) are numbered using consecutive natural numbers, what is
#   your estimate of $N$ the total number of locomotives operated by PKP?
#
#   Tell why the Maximum Likelihood principle may not yield satisfactory
#   results.
#
#   Use the Bayesian approach to find the posterior distribution over
#   the number of locomotives. Then compute the expected count of
#   locomotives. For the prior use the power law:
#   \begin{equation}
#   p(N) =  \frac{1}{N^\alpha}\frac{1}{\zeta(\alpha,1)},
#   \end{equation}
#   where the $\zeta(s,q)=\sum_{n=0}^{\infty}\frac{1}{(q+n)^s}$ is the
#   Hurvitz Zeta function
#   (https://en.wikipedia.org/wiki/Hurwitz_zeta_function)
#   available in Python as `scipy.special.zeta`. The use of the
#   power law is motivated by the observation that the frequency of
#   occurrence of a company is inversely proportional to its size (see
#   also: R.L. Axtell, Zipf distribution of US firm sizes
#   https://www.sciencemag.org/content/293/5536/1818).
#
#   How would your estimate change after seeing 5 locomotives, with the
#   biggest serial number among them being 50?
#
#   **Note**: During the Second World War, a similar problem was
#   encountered while trying to estimate the total German tank
#   production from the serial numbers of captured machines. The
#   statistical estimates were the most precise!

# %%
from scipy.special import zeta as zeta


def prior(n):
    return 1.0 / (n**alpha * zeta(alpha, 1))


upper_bound = 100
nums = [3, 17, 50, 24, 43]
args = np.linspace(1, upper_bound, upper_bound)

alpha = 5 


probabilities = prior(args)
probabilities /= np.sum(probabilities)

max_num = -1

#subplot(1, 1, 1)
for i in range (len(nums)):
    for j in range (len(args)):
        #print(i, j, args[j], nums[i])
        max_num = max(max_num, nums[i])
        if args[j] < max_num:
            probabilities[j] = 0.0
        else:
            curr_n = args[j]
            probabilities[j] *= 1.0 / (curr_n - i)
    #print (probabilities[48:53])
    probabilities /= np.sum(probabilities)
    plot(args, probabilities, label='after seeing {}'.format(i+1))
#print (probabilities[48:53])
EX = np.sum(args * probabilities)
print("Expected number of locomotives after seeing 3, 17, 50, 24 and 43: {}".format(EX))
legend()
# Out:
# Expected number of locomotives after seeing 3, 17, 50, 24 and 43: 55.4864439562
